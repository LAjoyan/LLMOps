# %% [markdown]
# # Explore chat i Pydantic AI

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv
from constants import MODEL_SMALL, MODEL_MEDIUM, MODEL_LARGE

# overrides eventual caching of environmnet variables so that we alsways
load_dotenv(override=True)

agent = Agent(
    model=MODEL_SMALL,
    system_prompt="Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.",
    retries=1
)

result = await agent.run('Why is it not sunny in göteborg')

# %%
print(result.output)
# Out:
# Why did the programmer settle for a rainy day in Göteborg?
# Because even code needs a little *cloud*-style atmosphere! ☔️💻😄
#
# P.S. If you want a really punchy response, try this:
# `sysinfo()` in Python is the real sunshine! ☀️✨
# #ProgrammingVibes #GöteborgWeather

# %%
result = await agent.run('what did i just ask you?')
print(result.output)
# Out:
# Oh boy, you asked a *quest*! 😄
# So, what did you prompt? Let me crack a code with a joke! 🤖✨
#
# Want me to give you a programming-related pun that’ll hit your bug? 😎💻
#
# P.S. If you're ready for more fun, just say the word — I’m always here to debug your thoughts with a smile! 😁

# %% [markdown]
# # History stored in all_messages

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 16, 21, 49, 985238, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what did i just ask you?', timestamp=datetime.datetime(2026, 4, 13, 16, 21, 49, 985250, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 16, 21, 49, 985830, tzinfo=datetime.timezone.utc), run_id='019d87a6-3520-7491-997d-c2a90dfbb1d4'),
#  ModelResponse(parts=[TextPart(content="Oh boy, you asked a *quest*! 😄  \nSo, what did you prompt? Let me crack a code with a joke! 🤖✨\n\nWant me to give you a programming-related pun that’ll hit your bug? 😎💻  \n\nP.S. If you're ready for more fun, just say the word — I’m always here to debug your thoughts with a smile! 😁")], usage=RequestUsage(input_tokens=49, output_tokens=88, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 16, 21, 51, 658654, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 16, 21, 49, tzinfo=TzInfo(0))}, provider_response_id='gen-1776097309-3AaFXNU8YWfSmDACN0tY', finish_reason='stop', run_id='019d87a6-3520-7491-997d-c2a90dfbb1d4')]

# %%
result = await agent.run(
    "Give me a cool joke about H2O", message_history=result.all_messages()
)
print(result.output)
# Out:
# Why did the water molecule join a band?
# Because it wanted to *hydrate* its vibe! 💧🎶
#
# *(Joke explained: Water loves to feel the rhythm of life — whether it’s in a party or a cool verse!)*
#
# Anything else you need? 😄

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 16, 21, 49, 985238, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what did i just ask you?', timestamp=datetime.datetime(2026, 4, 13, 16, 21, 49, 985250, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 16, 21, 49, 985830, tzinfo=datetime.timezone.utc), run_id='019d87a6-3520-7491-997d-c2a90dfbb1d4'),
#  ModelResponse(parts=[TextPart(content="Oh boy, you asked a *quest*! 😄  \nSo, what did you prompt? Let me crack a code with a joke! 🤖✨\n\nWant me to give you a programming-related pun that’ll hit your bug? 😎💻  \n\nP.S. If you're ready for more fun, just say the word — I’m always here to debug your thoughts with a smile! 😁")], usage=RequestUsage(input_tokens=49, output_tokens=88, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 16, 21, 51, 658654, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 16, 21, 49, tzinfo=TzInfo(0))}, provider_response_id='gen-1776097309-3AaFXNU8YWfSmDACN0tY', finish_reason='stop', run_id='019d87a6-3520-7491-997d-c2a90dfbb1d4'),
#  ModelRequest(parts=[UserPromptPart(content='Give me a cool joke about H2O', timestamp=datetime.datetime(2026, 4, 13, 16, 22, 6, 971297, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 16, 22, 6, 971435, tzinfo=datetime.timezone.utc), run_id='019d87a6-777a-718c-983e-3c1b72271c40'),
#  ModelResponse(parts=[TextPart(content='Why did the water molecule join a band?  \nBecause it wanted to *hydrate* its vibe! 💧🎶  \n\n*(Joke explained: Water loves to feel the rhythm of life — whether it’s in a party or a cool verse!)*  \n\nAnything else you need? 😄')], usage=RequestUsage(input_tokens=155, output_tokens=68, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 16, 22, 8, 41087, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 16, 22, 6, tzinfo=TzInfo(0))}, provider_response_id='gen-1776097326-SX21NtrjRTASF5fnbImE', finish_reason='stop', run_id='019d87a6-777a-718c-983e-3c1b72271c40')]

# %% [markdown]
# ## Testing out API

# %%
import httpx

prompt = "what is a dendrogram"

chat_response = httpx.post(
    "http://localhost:8000/chat",
    json={
        "question": prompt,
        "message_history": [],
    },
)

chat_response
# Out:
# <Response [200 OK]>

# %%
chat_response.json().get('response')
# Out:
# "A dendrogram is like a family tree, but for data! 🌳 It shows how things are related, like in clustering or hierarchal structures. 🤖\n\nNow, here's a programming joke:  \nWhy did the algorithm go on date night?  \nBecause it wanted to build a *deep* relationship! 😄🧑\u200d💻  \n\nLet me know if you need more tech laughs! 😊"
