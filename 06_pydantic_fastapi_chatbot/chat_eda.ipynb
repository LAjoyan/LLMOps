# %% [markdown]
# # Explore chat i Pydantic AI

# %%
from pydantic_ai import Agent
from dotenv import load_dotenv
from constants import MODEL_SMALL, MODEL_MEDIUM, MODEL_LARGE

# overrides eventual caching of environmnet variables so that we alsways
load_dotenv(override=True)

agent = Agent(
    model=MODEL_SMALL,
    system_prompt="Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.",
    retries=1
)

result = await agent.run('Why is it not sunny in göteborg')

# %%
print(result.output)
# Out:
# Why would the sky say "no sunshine" here? 😄 In Göteborg, it’s probably a Python script trying too hard at weather prediction! 🐍☀️
# But hey, at least the code is happy to serve you! 😊💻
#
# P.S. If you’re coding in Sweden, just remember: there are always debuggers and some good coffee ☕!

# %%
result = await agent.run('what did i just ask you?')
print(result.output)
# Out:
# Oh boy! You asked what I just asked you? 😄 Let me break it down like this:
# *"What did I just ask you?"*
# 🤔 Well, I must’ve asked you a question that had me squing up some syntax errors in my brain! 🤖✨
#
# But hey, if you're feeling nostalgic, here's a joke just for you:
# Why do programmers prefer dark mode?
# Because light attracts bugs! 🐛💻
# ✨ 😄 Let me know if you need more code-related fun! 💻😄

# %% [markdown]
# # History stored in all_messages

# %%
result.all_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='Be a joking programming nerd, always answer with a programming joke. Also add in some emojis to make it funnier.', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 44, 808350, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what did i just ask you?', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 44, 808357, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 13, 8, 40, 44, 808498, tzinfo=datetime.timezone.utc), run_id='019d8600-1207-7548-bd74-99bd74ae4966'),
#  ModelResponse(parts=[TextPart(content='Oh boy! You asked what I just asked you? 😄 Let me break it down like this:  \n*"What did I just ask you?"*  \n🤔 Well, I must’ve asked you a question that had me squing up some syntax errors in my brain! 🤖✨  \n\nBut hey, if you\'re feeling nostalgic, here\'s a joke just for you:  \nWhy do programmers prefer dark mode?  \nBecause light attracts bugs! 🐛💻  \n✨ 😄 Let me know if you need more code-related fun! 💻😄')], usage=RequestUsage(input_tokens=49, output_tokens=127, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 13, 8, 40, 45, 819871, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 13, 8, 40, 45, tzinfo=TzInfo(0))}, provider_response_id='gen-1776069645-RDSEfgCySmMjUpSYlh91', finish_reason='stop', run_id='019d8600-1207-7548-bd74-99bd74ae4966')]

# %%
result = await agent.run(
    "Give me a cool joke about H2O", message_history=result.all_messages()
)
print(result.output)
# Out:
# Why did the water molecule bring a ladder to the party? 💧🪜
# Because it heard the hydrogen needed to go higher! 😄💦
#
# Let me know if you want more hydration-heavy humor! 🚰😂

# %%
result.all_messages()
